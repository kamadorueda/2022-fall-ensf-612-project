# %%
import pyspark
import numpy as np
import pandas as pd

df = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/shared_uploads/runze.yu@ucalgary.ca/content.csv")

# %%
df.show()
# Out:
# +------------+---------+--------------------+
# |issue_number|was_fixed|             content|
# +------------+---------+--------------------+
# |       18544|     True|powershel ssh ter...|
# |       18540|     True|handl quotat mark...|
# |       18501|    False|problem psnativec...|
# |       18500|     True|question download...|
# |       18497|     True|defin env var inl...|
# |       18490|    False|writeerror prefix...|
# |       18489|     True|semanticvers doe ...|
# |       18485|     True|errorresponseexce...|
# |       18478|     True|pleas remov refer...|
# |       18476|     True|class regist erro...|
# |       18463|     True|gethelp paramet d...|
# |       18460|     True|invokepowershel s...|
# |       18459|    False|sendmailmessag se...|
# |       18436|     True|switchprocess bro...|
# |       18433|     True|switchprocess use...|
# |       18432|     True|switchprocess exe...|
# |       18431|     True|disablewindowsopt...|
# |       18424|     True|systemprivateuri ...|
# |       18423|     True|windowstyl hidden...|
# |       18422|     True|releas process vx...|
# +------------+---------+--------------------+
# only showing top 20 rows

# %%
df.groupBy("was_fixed").count().show()
# Out:
# +---------+-----+
# |was_fixed|count|
# +---------+-----+
# |    False|  370|
# |     True|  630|
# +---------+-----+

# %%
import pyspark.ml.feature
from pyspark.ml.feature import Tokenizer as Tok, StopWordsRemover as SWR, CountVectorizer as CV, IDF, StringIndexer as SI

# %%
tokenizer = Tok(inputCol = "content", outputCol = "mytokens")

stop_rem = SWR(inputCol = "mytokens", outputCol = "filtered_tokens")

vectorizer = CV(inputCol = "filtered_tokens", outputCol = "rawFeatures")

idf = IDF(inputCol = "rawFeatures", outputCol = "vectorFeatures")

# %%
labelEncoder = SI(inputCol = 'was_fixed', outputCol = 'label').fit(df)

# %%
labelEncoder.transform(df).show()
# Out:
# +------------+---------+--------------------+-----+
# |issue_number|was_fixed|             content|label|
# +------------+---------+--------------------+-----+
# |       18544|     True|powershel ssh ter...|  0.0|
# |       18540|     True|handl quotat mark...|  0.0|
# |       18501|    False|problem psnativec...|  1.0|
# |       18500|     True|question download...|  0.0|
# |       18497|     True|defin env var inl...|  0.0|
# |       18490|    False|writeerror prefix...|  1.0|
# |       18489|     True|semanticvers doe ...|  0.0|
# |       18485|     True|errorresponseexce...|  0.0|
# |       18478|     True|pleas remov refer...|  0.0|
# |       18476|     True|class regist erro...|  0.0|
# |       18463|     True|gethelp paramet d...|  0.0|
# |       18460|     True|invokepowershel s...|  0.0|
# |       18459|    False|sendmailmessag se...|  1.0|
# |       18436|     True|switchprocess bro...|  0.0|
# |       18433|     True|switchprocess use...|  0.0|
# |       18432|     True|switchprocess exe...|  0.0|
# |       18431|     True|disablewindowsopt...|  0.0|
# |       18424|     True|systemprivateuri ...|  0.0|
# |       18423|     True|windowstyl hidden...|  0.0|
# |       18422|     True|releas process vx...|  0.0|
# +------------+---------+--------------------+-----+
# only showing top 20 rows

# %%
labelEncoder.labels
# Out:
# Out[241]: ['True', 'False']

# %%
df = labelEncoder.transform(df)

# %%
(trainDF, testDF) = df.randomSplit((0.7, 0.3), seed = 42)
trainDF.show(5)
# Out:
# +------------+---------+--------------------+-----+
# |issue_number|was_fixed|             content|label|
# +------------+---------+--------------------+-----+
# |       15194|     True|question chang th...|  0.0|
# |       15196|     True|datat type call g...|  0.0|
# |       15201|     True|recurs option get...|  0.0|
# |       15202|     True|run wget output p...|  0.0|
# |       15205|     True|command line uac ...|  0.0|
# +------------+---------+--------------------+-----+
# only showing top 5 rows

# %%
from pyspark.ml.classification import LogisticRegression as LR, LinearSVC as SVC, NaiveBayes as NB

lr = LR(featuresCol = "vectorFeatures", labelCol = 'label')
svc = SVC(featuresCol = "vectorFeatures", labelCol = 'label')
nb = NB(featuresCol = "vectorFeatures", labelCol = 'label')

# %%
from pyspark.ml import Pipeline

pipeline_lr = Pipeline(stages = [tokenizer, stop_rem, vectorizer, idf, lr])
pipeline_nb = Pipeline(stages = [tokenizer, stop_rem, vectorizer, idf, nb])
pipeline_svc = Pipeline(stages = [tokenizer, stop_rem, vectorizer, idf, svc])

# %%
lr_model = pipeline_lr.fit(trainDF)
nb_model = pipeline_nb.fit(trainDF)
svc_model = pipeline_svc.fit(trainDF)

# %%
predictions_lr = lr_model.transform(testDF)
predictions_lr.show()
# Out:
# +------------+---------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |issue_number|was_fixed|             content|label|            mytokens|     filtered_tokens|         rawFeatures|      vectorFeatures|       rawPrediction|         probability|prediction|
# +------------+---------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |       15200|    False|windows open powe...|  1.0|[windows, open, p...|[windows, open, p...|(10700,[0,2,4,5,9...|(10700,[0,2,4,5,9...|[-42.131045264098...|[5.04335483642045...|       1.0|
# |       15206|    False|defer input pipel...|  1.0|[defer, input, pi...|[defer, input, pi...|(10700,[0,2,3,7,1...|(10700,[0,2,3,7,1...|[2.81474488353407...|[0.94346742850466...|       0.0|
# |       15213|    False|distribut support...|  1.0|[distribut, suppo...|[distribut, suppo...|(10700,[0,2,6,10,...|(10700,[0,2,6,10,...|[-114.96630320193...|[1.17697954332140...|       1.0|
# |       15214|    False|releas process vx...|  1.0|[releas, process,...|[releas, process,...|(10700,[2,6,10,12...|(10700,[2,6,10,12...|[-129.12183296521...|[8.37723020541807...|       1.0|
# |       15218|    False|featur request su...|  1.0|[featur, request,...|[featur, request,...|(10700,[0,1,15,16...|(10700,[0,1,15,16...|[-43.734891293636...|[1.01432713679356...|       1.0|
# |       15220|    False|distribut support...|  1.0|[distribut, suppo...|[distribut, suppo...|(10700,[0,2,6,10,...|(10700,[0,2,6,10,...|[-114.96630320193...|[1.17697954332140...|       1.0|
# |       15229|     True|consol output ssh...|  0.0|[consol, output, ...|[consol, output, ...|(10700,[0,2,4,5,6...|(10700,[0,2,4,5,6...|[-40.284068781806...|[3.19779942029345...|       1.0|
# |       15237|    False|unabl remov direc...|  1.0|[unabl, remov, di...|[unabl, remov, di...|(10700,[0,2,4,5,6...|(10700,[0,2,4,5,6...|[-4.2615848868383...|[0.01390389384663...|       1.0|
# |       15244|     True|updat tag master ...|  0.0|[updat, tag, mast...|[updat, tag, mast...|(10700,[0,2,4,9,1...|(10700,[0,2,4,9,1...|[1.33433701424125...|[0.79155712290776...|       0.0|
# |       15246|    False|request guidanc g...|  1.0|[request, guidanc...|[request, guidanc...|(10700,[2,24,37,3...|(10700,[2,24,37,3...|[-0.5418645893369...|[0.36775393796723...|       1.0|
# |       15247|    False|support get objec...|  1.0|[support, get, ob...|[support, get, ob...|(10700,[0,2,3,12,...|(10700,[0,2,3,12,...|[-29.518489143090...|[1.51454803214010...|       1.0|
# |       15254|     True|powershel process...|  0.0|[powershel, proce...|[powershel, proce...|(10700,[0,1,2,4,5...|(10700,[0,1,2,4,5...|[-47.211293167402...|[3.13614326511243...|       1.0|
# |       15255|    False|bug report window...|  1.0|[bug, report, win...|[bug, report, win...|(10700,[0,2,4,5,9...|(10700,[0,2,4,5,9...|[-43.750982522816...|[9.98135983511216...|       1.0|
# |       15261|    False|experiment featur...|  1.0|[experiment, feat...|[experiment, feat...|(10700,[0,2,4,5,1...|(10700,[0,2,4,5,1...|[20.2451542451544...|[0.99999999838697...|       0.0|
# |       15269|     True|gptruste object r...|  0.0|[gptruste, object...|[gptruste, object...|(10700,[0,3,4,5,6...|(10700,[0,3,4,5,6...|[5.43189709899334...|[0.99564426689279...|       0.0|
# |       15271|     True|featur request pr...|  0.0|[featur, request,...|[featur, request,...|(10700,[0,1,4,6,1...|(10700,[0,1,4,6,1...|[-49.779782528050...|[2.40389302713317...|       1.0|
# |       15272|    False|pipe invokerestme...|  1.0|[pipe, invokerest...|[pipe, invokerest...|(10700,[0,2,4,5,6...|(10700,[0,2,4,5,6...|[5.92097064469493...|[0.99732458199696...|       0.0|
# |       15281|     True|pass file functio...|  0.0|[pass, file, func...|[pass, file, func...|(10700,[0,4,6,12,...|(10700,[0,4,6,12,...|[18.2940789076928...|[0.99999998865034...|       0.0|
# |       15290|    False|pwsh hung becaus ...|  1.0|[pwsh, hung, beca...|[pwsh, hung, beca...|(10700,[1,2,12,14...|(10700,[1,2,12,14...|[-23.353045160227...|[7.20943700273108...|       1.0|
# |       15292|     True|appx modul wo nt ...|  0.0|[appx, modul, wo,...|[appx, modul, wo,...|(10700,[0,1,2,4,5...|(10700,[0,1,2,4,5...|[-11.695252417384...|[8.33321892683839...|       1.0|
# +------------+---------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
predictions_nb = nb_model.transform(testDF)
predictions_nb.show()
# Out:
# +------------+---------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |issue_number|was_fixed|             content|label|            mytokens|     filtered_tokens|         rawFeatures|      vectorFeatures|       rawPrediction|         probability|prediction|
# +------------+---------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |       15200|    False|windows open powe...|  1.0|[windows, open, p...|[windows, open, p...|(10700,[0,2,4,5,9...|(10700,[0,2,4,5,9...|[-477.45632893044...|[3.81294528612891...|       1.0|
# |       15206|    False|defer input pipel...|  1.0|[defer, input, pi...|[defer, input, pi...|(10700,[0,2,3,7,1...|(10700,[0,2,3,7,1...|[-2397.0383477486...|[1.0,2.5977677366...|       0.0|
# |       15213|    False|distribut support...|  1.0|[distribut, suppo...|[distribut, suppo...|(10700,[0,2,6,10,...|(10700,[0,2,6,10,...|[-2043.5079057144...|[1.24133909881018...|       1.0|
# |       15214|    False|releas process vx...|  1.0|[releas, process,...|[releas, process,...|(10700,[2,6,10,12...|(10700,[2,6,10,12...|[-3694.2940386377...|[3.23450690438524...|       1.0|
# |       15218|    False|featur request su...|  1.0|[featur, request,...|[featur, request,...|(10700,[0,1,15,16...|(10700,[0,1,15,16...|[-733.70150242143...|[5.16112073700192...|       1.0|
# |       15220|    False|distribut support...|  1.0|[distribut, suppo...|[distribut, suppo...|(10700,[0,2,6,10,...|(10700,[0,2,6,10,...|[-2043.5079057144...|[1.24133909881018...|       1.0|
# |       15229|     True|consol output ssh...|  0.0|[consol, output, ...|[consol, output, ...|(10700,[0,2,4,5,6...|(10700,[0,2,4,5,6...|[-3319.4529956338...|[5.48418367587765...|       1.0|
# |       15237|    False|unabl remov direc...|  1.0|[unabl, remov, di...|[unabl, remov, di...|(10700,[0,2,4,5,6...|(10700,[0,2,4,5,6...|[-1805.6941064362...|[4.30645647503344...|       1.0|
# |       15244|     True|updat tag master ...|  0.0|[updat, tag, mast...|[updat, tag, mast...|(10700,[0,2,4,9,1...|(10700,[0,2,4,9,1...|[-886.98998871872...|[0.99976657745386...|       0.0|
# |       15246|    False|request guidanc g...|  1.0|[request, guidanc...|[request, guidanc...|(10700,[2,24,37,3...|(10700,[2,24,37,3...|[-2027.8767924677...|[1.0,9.1858175777...|       0.0|
# |       15247|    False|support get objec...|  1.0|[support, get, ob...|[support, get, ob...|(10700,[0,2,3,12,...|(10700,[0,2,3,12,...|[-2947.3344687612...|[2.05940054346714...|       1.0|
# |       15254|     True|powershel process...|  0.0|[powershel, proce...|[powershel, proce...|(10700,[0,1,2,4,5...|(10700,[0,1,2,4,5...|[-4801.6254802244...|[1.0,3.5814245805...|       0.0|
# |       15255|    False|bug report window...|  1.0|[bug, report, win...|[bug, report, win...|(10700,[0,2,4,5,9...|(10700,[0,2,4,5,9...|[-465.47019455207...|[3.23640431703542...|       1.0|
# |       15261|    False|experiment featur...|  1.0|[experiment, feat...|[experiment, feat...|(10700,[0,2,4,5,1...|(10700,[0,2,4,5,1...|[-2071.3982839079...|[1.0,7.9141996392...|       0.0|
# |       15269|     True|gptruste object r...|  0.0|[gptruste, object...|[gptruste, object...|(10700,[0,3,4,5,6...|(10700,[0,3,4,5,6...|[-1353.2312754273...|[0.99996997585041...|       0.0|
# |       15271|     True|featur request pr...|  0.0|[featur, request,...|[featur, request,...|(10700,[0,1,4,6,1...|(10700,[0,1,4,6,1...|[-2131.8205487803...|[8.70393107758971...|       1.0|
# |       15272|    False|pipe invokerestme...|  1.0|[pipe, invokerest...|[pipe, invokerest...|(10700,[0,2,4,5,6...|(10700,[0,2,4,5,6...|[-2690.3084867785...|[1.0,8.5618295063...|       0.0|
# |       15281|     True|pass file functio...|  0.0|[pass, file, func...|[pass, file, func...|(10700,[0,4,6,12,...|(10700,[0,4,6,12,...|[-1144.8035410081...|[1.0,3.3700386509...|       0.0|
# |       15290|    False|pwsh hung becaus ...|  1.0|[pwsh, hung, beca...|[pwsh, hung, beca...|(10700,[1,2,12,14...|(10700,[1,2,12,14...|[-1316.0191908505...|[1.22771676870254...|       1.0|
# |       15292|     True|appx modul wo nt ...|  0.0|[appx, modul, wo,...|[appx, modul, wo,...|(10700,[0,1,2,4,5...|(10700,[0,1,2,4,5...|[-1483.9410770095...|[0.99999999999999...|       0.0|
# +------------+---------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
predictions_svc = svc_model.transform(testDF)
predictions_svc.show()
# Out:
# +------------+---------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |issue_number|was_fixed|             content|label|            mytokens|     filtered_tokens|         rawFeatures|      vectorFeatures|       rawPrediction|prediction|
# +------------+---------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# |       15200|    False|windows open powe...|  1.0|[windows, open, p...|[windows, open, p...|(10700,[0,2,4,5,9...|(10700,[0,2,4,5,9...|[-1.3072710266530...|       1.0|
# |       15206|    False|defer input pipel...|  1.0|[defer, input, pi...|[defer, input, pi...|(10700,[0,2,3,7,1...|(10700,[0,2,3,7,1...|[0.20080689702196...|       0.0|
# |       15213|    False|distribut support...|  1.0|[distribut, suppo...|[distribut, suppo...|(10700,[0,2,6,10,...|(10700,[0,2,6,10,...|[-3.2027016806537...|       1.0|
# |       15214|    False|releas process vx...|  1.0|[releas, process,...|[releas, process,...|(10700,[2,6,10,12...|(10700,[2,6,10,12...|[-1.6387477982326...|       1.0|
# |       15218|    False|featur request su...|  1.0|[featur, request,...|[featur, request,...|(10700,[0,1,15,16...|(10700,[0,1,15,16...|[-1.0426918269476...|       1.0|
# |       15220|    False|distribut support...|  1.0|[distribut, suppo...|[distribut, suppo...|(10700,[0,2,6,10,...|(10700,[0,2,6,10,...|[-3.2027016806537...|       1.0|
# |       15229|     True|consol output ssh...|  0.0|[consol, output, ...|[consol, output, ...|(10700,[0,2,4,5,6...|(10700,[0,2,4,5,6...|[-2.5048901657437...|       1.0|
# |       15237|    False|unabl remov direc...|  1.0|[unabl, remov, di...|[unabl, remov, di...|(10700,[0,2,4,5,6...|(10700,[0,2,4,5,6...|[-0.2330348785726...|       1.0|
# |       15244|     True|updat tag master ...|  0.0|[updat, tag, mast...|[updat, tag, mast...|(10700,[0,2,4,9,1...|(10700,[0,2,4,9,1...|[0.19454466718783...|       0.0|
# |       15246|    False|request guidanc g...|  1.0|[request, guidanc...|[request, guidanc...|(10700,[2,24,37,3...|(10700,[2,24,37,3...|[0.00280484940948...|       0.0|
# |       15247|    False|support get objec...|  1.0|[support, get, ob...|[support, get, ob...|(10700,[0,2,3,12,...|(10700,[0,2,3,12,...|[-1.9831694044926...|       1.0|
# |       15254|     True|powershel process...|  0.0|[powershel, proce...|[powershel, proce...|(10700,[0,1,2,4,5...|(10700,[0,1,2,4,5...|[-1.6476170830662...|       1.0|
# |       15255|    False|bug report window...|  1.0|[bug, report, win...|[bug, report, win...|(10700,[0,2,4,5,9...|(10700,[0,2,4,5,9...|[-1.4531353454543...|       1.0|
# |       15261|    False|experiment featur...|  1.0|[experiment, feat...|[experiment, feat...|(10700,[0,2,4,5,1...|(10700,[0,2,4,5,1...|[0.67684396861757...|       0.0|
# |       15269|     True|gptruste object r...|  0.0|[gptruste, object...|[gptruste, object...|(10700,[0,3,4,5,6...|(10700,[0,3,4,5,6...|[0.34270431795037...|       0.0|
# |       15271|     True|featur request pr...|  0.0|[featur, request,...|[featur, request,...|(10700,[0,1,4,6,1...|(10700,[0,1,4,6,1...|[-1.0575907648020...|       1.0|
# |       15272|    False|pipe invokerestme...|  1.0|[pipe, invokerest...|[pipe, invokerest...|(10700,[0,2,4,5,6...|(10700,[0,2,4,5,6...|[-0.0015122859885...|       1.0|
# |       15281|     True|pass file functio...|  0.0|[pass, file, func...|[pass, file, func...|(10700,[0,4,6,12,...|(10700,[0,4,6,12,...|[0.74813477191512...|       0.0|
# |       15290|    False|pwsh hung becaus ...|  1.0|[pwsh, hung, beca...|[pwsh, hung, beca...|(10700,[1,2,12,14...|(10700,[1,2,12,14...|[-0.4310971909105...|       1.0|
# |       15292|     True|appx modul wo nt ...|  0.0|[appx, modul, wo,...|[appx, modul, wo,...|(10700,[0,1,2,4,5...|(10700,[0,1,2,4,5...|[-0.4146422489912...|       1.0|
# +------------+---------+--------------------+-----+--------------------+--------------------+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
predictions_lr.select('rawPrediction', 'probability', 'was_fixed', 'label',  'prediction').show()
# Out:
# +--------------------+--------------------+---------+-----+----------+
# |       rawPrediction|         probability|was_fixed|label|prediction|
# +--------------------+--------------------+---------+-----+----------+
# |[-42.131045264098...|[5.04335483642045...|    False|  1.0|       1.0|
# |[2.81474488353407...|[0.94346742850466...|    False|  1.0|       0.0|
# |[-114.96630320193...|[1.17697954332140...|    False|  1.0|       1.0|
# |[-129.12183296521...|[8.37723020541807...|    False|  1.0|       1.0|
# |[-43.734891293636...|[1.01432713679356...|    False|  1.0|       1.0|
# |[-114.96630320193...|[1.17697954332140...|    False|  1.0|       1.0|
# |[-40.284068781806...|[3.19779942029345...|     True|  0.0|       1.0|
# |[-4.2615848868383...|[0.01390389384663...|    False|  1.0|       1.0|
# |[1.33433701424125...|[0.79155712290776...|     True|  0.0|       0.0|
# |[-0.5418645893369...|[0.36775393796723...|    False|  1.0|       1.0|
# |[-29.518489143090...|[1.51454803214010...|    False|  1.0|       1.0|
# |[-47.211293167402...|[3.13614326511243...|     True|  0.0|       1.0|
# |[-43.750982522816...|[9.98135983511216...|    False|  1.0|       1.0|
# |[20.2451542451544...|[0.99999999838697...|    False|  1.0|       0.0|
# |[5.43189709899334...|[0.99564426689279...|     True|  0.0|       0.0|
# |[-49.779782528050...|[2.40389302713317...|     True|  0.0|       1.0|
# |[5.92097064469493...|[0.99732458199696...|    False|  1.0|       0.0|
# |[18.2940789076928...|[0.99999998865034...|     True|  0.0|       0.0|
# |[-23.353045160227...|[7.20943700273108...|    False|  1.0|       1.0|
# |[-11.695252417384...|[8.33321892683839...|     True|  0.0|       1.0|
# +--------------------+--------------------+---------+-----+----------+
# only showing top 20 rows

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator as MCE

eval = MCE(labelCol = 'label', predictionCol = 'prediction', metricName = 'accuracy')

# %%
from pyspark.mllib.evaluation import MulticlassMetrics as MM

lr_metric = MM(predictions_lr['label', 'prediction'].rdd)
nb_metric = MM(predictions_nb['label', 'prediction'].rdd)
svc_metric = MM(predictions_svc['label', 'prediction'].rdd)

print("Accuracy LR:", lr_metric.accuracy)
print("Precision LR:", lr_metric.precision(1.0))
print("Recall LR:", lr_metric.recall(1.0))
print("F1 Score LR:", lr_metric.fMeasure(1.0))

print(" ")

print("Accuracy NB:", nb_metric.accuracy)
print("Precision NB:", nb_metric.precision(1.0))
print("Recall NB:", nb_metric.recall(1.0))
print("F1 Score NB:", nb_metric.fMeasure(1.0))

print(" ")

print("Accuracy SVC:", svc_metric.accuracy)
print("Precision SVC:", svc_metric.precision(1.0))
print("Recall SVC:", svc_metric.recall(1.0))
print("F1 Score SVC:", svc_metric.fMeasure(1.0))
# Out:
# Accuracy LR: 0.57421875
# Precision LR: 0.4639175257731959
# Recall LR: 0.4411764705882353
# F1 Score LR: 0.4522613065326633
#
# Accuracy NB: 0.6171875
# Precision NB: 0.5360824742268041
# Recall NB: 0.49523809523809526
# F1 Score NB: 0.5148514851485149
#
# Accuracy SVC: 0.58984375
# Precision SVC: 0.4536082474226804
# Recall SVC: 0.4583333333333333
# F1 Score SVC: 0.4559585492227979
